# %%
import http.client
import pandas as pd
import json
from pandas import json_normalize
import time

# Read the API key from the text file
api_key_file = r".../Code/rapidapi_key.txt"
with open(api_key_file, 'r') as file:
    rapidapi_key = file.read().strip()

# Define the API host
host = "zillow-com1.p.rapidapi.com"

# Initialize the connection
conn = http.client.HTTPSConnection(host)

# Define the headers
headers = {
    'x-rapidapi-key': rapidapi_key,
    'x-rapidapi-host': host
}

# Define the path to the CSV file
csv_path = r".../Data/zpid_difference.csv"

# Read the CSV file into a DataFrame
properties_df = pd.read_csv(csv_path)

# Extract the 'zpid' column and convert it to a list
zpid_list = properties_df['zpid'].tolist()

# Initialize a list to store the results
results = []

# Loop through the list of zpids and make API requests
for zpid in zpid_list:
    # Define the request URL for the current zpid
    request_url = f"/property?zpid={zpid}"
    
    # Make the GET request
    conn.request("GET", request_url, headers=headers)
    
    # Get the response
    res = conn.getresponse()
    data = res.read()
    
    # Decode the response data
    decoded_data = data.decode("utf-8")
    
    # Parse the JSON data
    json_data = json.loads(decoded_data)
    
    # Append the JSON data to the results list
    results.append(json_data)
    
    # Print the JSON data for debugging
    print(json.dumps(json_data, indent=2))
    
    # Wait for half a second to avoid exceeding the rate limit
    time.sleep(0.5)

# Close the connection
conn.close()

# Convert the list of JSON responses to a DataFrame
results_df = json_normalize(results)

# Convert results_df to a DataFrame explicitly (though it already is one)
results_df = pd.DataFrame(results_df)

# Define the path to save the CSV
csv_path_results = r".../Data/property_details_missing.csv"

# Save the DataFrame to a CSV file
results_df.to_csv(csv_path_results, index=False)

print(f"Property details saved to {csv_path_results}")
# Out:
# {
#   "listingProvider": null,
#   "zpid": 62546314,
#   "buildingPermits": null,
#   "propertyTaxRate": 1.66,
#   "contact_recipients": [
#     {
#       "agent_reason": 1,
#       "zpro": null,
#       "recent_sales": 1,
#       "review_count": 117,
#       "display_name": "Kristopher Tramont",
#       "zuid": "X1-ZU113y085epnwg9_97i75",
#       "rating_average": 5,
#       "badge_type": "Premier Agent",
#       "phone": {
#         "prefix": "606",
#         "areacode": "860",
#         "number": "3971"
#       },
#       "image_url": "https://photos.zillowstatic.com/h_n/ISb1zc1cbb3w2j0000000000.jpg"
#     }
#   ],
#   "zipcode": "06370",
#   "openHouseSchedule": {},
#   "longitude": -72.204254,
#   "zestimateLowPercent": "8",
#   "address": {
#     "community": null,
#     "city": "Oakdale",
#     "state": "CT",
#     "neighborhood": null,
#     "subdivision": null,
#     "streetAddress": "50 Laurel Point Dr",
#     "zipcode": "06370"
#   },
#   "cityId": 12820,
# ...
